# %%
from sklearn.decomposition import PCA
import splitfolders
import zipfile,os
import numpy as np
from keras.layers import Dense, Dropout, GaussianNoise, Conv1D
from sklearn.preprocessing import MinMaxScaler
from sklearn.neural_network import MLPClassifier

# %%
local_zip = 'img.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall()
zip_ref.close()

base_dir ='img'

# %%
splitfolders.ratio(base_dir, output=base_dir, ratio=(0.7,0.3))
 
train = os.path.join(base_dir, 'train')
val = os.path.join(base_dir, 'val')
# Out:
# Copying files: 420 files [00:03, 126.90 files/s]

# %%
os.listdir('img/train')
os.listdir('img/val')
# Out:
# ['AAA',
#  'ABI',
#  'AFI',
#  'AGH',
#  'AIL',
#  'ARL',
#  'ASA',
#  'BDL',
#  'DIA',
#  'DIO',
#  'DRA',
#  'EZA',
#  'FAR',
#  'FMR',
#  'FRS',
#  'GLA',
#  'GPS',
#  'HMA',
#  'HZR',
#  'IDR',
#  'KDA',
#  'MAA',
#  'MAJ',
#  'MFA',
#  'MFH',
#  'MGN',
#  'MMF',
#  'MRF',
#  'MSA',
#  'MZA',
#  'MZB',
#  'NIS',
#  'QTH',
#  'RCK',
#  'RKS',
#  'SHE',
#  'SNN',
#  'SVD',
#  'SYH',
#  'SYN',
#  'train',
#  'val',
#  'YSS',
#  'ZHT']

# %% [markdown]
# ### Pre-Processing

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
                rescale = 1./255,
                shear_range=0.2,
                zoom_range=0.2,
                horizontal_flip=True,
                fill_mode = 'nearest')

test_datagen = ImageDataGenerator(
                rescale = 1./255,
                shear_range=0.2,
                zoom_range=0.2,
                horizontal_flip=True,
                fill_mode = 'nearest')

# %%
train_generator = train_datagen.flow_from_directory(
        train,
        batch_size = 1,
        color_mode = 'grayscale',
        shuffle = False,
        class_mode = "categorical",
        target_size =  (100, 100))

test_generator = test_datagen.flow_from_directory(
        val,
        batch_size = 1,
        color_mode = 'grayscale',
        shuffle = False,
        class_mode = "categorical",
        target_size =  (100, 100))
# Out:
# Found 294 images belonging to 44 classes.
# Found 126 images belonging to 44 classes.

# %% [markdown]
# ### BPNN

# %%
X_train = train_generator[0][0][0].flatten()
for i in range(1, len(train_generator)):
    features = train_generator[i][0][0].flatten()
    X_train = np.vstack((X_train, features))

X_test = test_generator[0][0][0].flatten()
for i in range(1, len(test_generator)):
    features = test_generator[i][0][0].flatten()
    X_test = np.vstack((X_test, features))

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
Y_train = np.array(train_generator.labels)

# %%
pca=PCA(n_components=100, whiten=True)
pca.fit(X_train_scaled)
X_pca_train = pca.fit_transform(X_train_scaled)
X_pca_test = pca.transform(X_test_scaled)
pca_std = np.std(X_pca_train)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    GaussianNoise(pca_std),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(42, activation='softmax')
])

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='Adam',
              metrics=['accuracy'])

# %%
history=model.fit(X_pca_train, Y_train, epochs=100, batch_size=4, validation_split=0.3, verbose=2)
# Out:
# Epoch 1/100
# 52/52 - 0s - loss: 3.8056 - accuracy: 0.0244 - val_loss: 5.4483 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 52/52 - 0s - loss: 2.4280 - accuracy: 0.4293 - val_loss: 5.9761 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 52/52 - 0s - loss: 1.7455 - accuracy: 0.6341 - val_loss: 6.2964 - val_accuracy: 0.0112
# Epoch 4/100
# 52/52 - 0s - loss: 1.3953 - accuracy: 0.7415 - val_loss: 6.5366 - val_accuracy: 0.0112
# Epoch 5/100
# 52/52 - 0s - loss: 1.0062 - accuracy: 0.8000 - val_loss: 6.6713 - val_accuracy: 0.0225
# Epoch 6/100
# 52/52 - 0s - loss: 0.8105 - accuracy: 0.8634 - val_loss: 6.8354 - val_accuracy: 0.0225
# Epoch 7/100
# 52/52 - 0s - loss: 0.6248 - accuracy: 0.9073 - val_loss: 6.9557 - val_accuracy: 0.0112
# Epoch 8/100
# 52/52 - 0s - loss: 0.5364 - accuracy: 0.9024 - val_loss: 7.0932 - val_accuracy: 0.0112
# Epoch 9/100
# 52/52 - 0s - loss: 0.5003 - accuracy: 0.9220 - val_loss: 7.2241 - val_accuracy: 0.0112
# Epoch 10/100
# 52/52 - 0s - loss: 0.4626 - accuracy: 0.9122 - val_loss: 7.3159 - val_accuracy: 0.0112
# Epoch 11/100
# 52/52 - 0s - loss: 0.3699 - accuracy: 0.9171 - val_loss: 7.4096 - val_accuracy: 0.0112
# Epoch 12/100
# 52/52 - 0s - loss: 0.3813 - accuracy: 0.9268 - val_loss: 7.5117 - val_accuracy: 0.0112
# Epoch 13/100
# 52/52 - 0s - loss: 0.3306 - accuracy: 0.9317 - val_loss: 7.6060 - val_accuracy: 0.0112
# Epoch 14/100
# 52/52 - 0s - loss: 0.2997 - accuracy: 0.9268 - val_loss: 7.6590 - val_accuracy: 0.0112
# Epoch 15/100
# 52/52 - 0s - loss: 0.2412 - accuracy: 0.9659 - val_loss: 7.7193 - val_accuracy: 0.0112
# Epoch 16/100
# 52/52 - 0s - loss: 0.2697 - accuracy: 0.9512 - val_loss: 7.7783 - val_accuracy: 0.0112
# Epoch 17/100
# 52/52 - 0s - loss: 0.2850 - accuracy: 0.9317 - val_loss: 7.7722 - val_accuracy: 0.0112
# Epoch 18/100
# 52/52 - 0s - loss: 0.3075 - accuracy: 0.9171 - val_loss: 7.8360 - val_accuracy: 0.0112
# Epoch 19/100
# 52/52 - 0s - loss: 0.1911 - accuracy: 0.9610 - val_loss: 7.8790 - val_accuracy: 0.0112
# Epoch 20/100
# 52/52 - 0s - loss: 0.2567 - accuracy: 0.9268 - val_loss: 7.8983 - val_accuracy: 0.0112
# Epoch 21/100
# 52/52 - 0s - loss: 0.1849 - accuracy: 0.9659 - val_loss: 7.9813 - val_accuracy: 0.0112
# Epoch 22/100
# 52/52 - 0s - loss: 0.1904 - accuracy: 0.9610 - val_loss: 8.0502 - val_accuracy: 0.0112
# Epoch 23/100
# 52/52 - 0s - loss: 0.2376 - accuracy: 0.9463 - val_loss: 8.0711 - val_accuracy: 0.0112
# Epoch 24/100
# 52/52 - 0s - loss: 0.1868 - accuracy: 0.9463 - val_loss: 8.1258 - val_accuracy: 0.0112
# Epoch 25/100
# 52/52 - 0s - loss: 0.2561 - accuracy: 0.9220 - val_loss: 8.2278 - val_accuracy: 0.0112
# Epoch 26/100
# 52/52 - 0s - loss: 0.1722 - accuracy: 0.9415 - val_loss: 8.2710 - val_accuracy: 0.0225
# Epoch 27/100
# 52/52 - 0s - loss: 0.2312 - accuracy: 0.9317 - val_loss: 8.2190 - val_accuracy: 0.0112
# Epoch 28/100
# 52/52 - 0s - loss: 0.1329 - accuracy: 0.9707 - val_loss: 8.2391 - val_accuracy: 0.0112
# Epoch 29/100
# 52/52 - 0s - loss: 0.2151 - accuracy: 0.9366 - val_loss: 8.3189 - val_accuracy: 0.0112
# Epoch 30/100
# 52/52 - 0s - loss: 0.1643 - accuracy: 0.9561 - val_loss: 8.3305 - val_accuracy: 0.0112
# Epoch 31/100
# 52/52 - 0s - loss: 0.1833 - accuracy: 0.9561 - val_loss: 8.3102 - val_accuracy: 0.0112
# Epoch 32/100
# 52/52 - 0s - loss: 0.1702 - accuracy: 0.9512 - val_loss: 8.3573 - val_accuracy: 0.0112
# Epoch 33/100
# 52/52 - 0s - loss: 0.1687 - accuracy: 0.9610 - val_loss: 8.4253 - val_accuracy: 0.0112
# Epoch 34/100
# 52/52 - 0s - loss: 0.2737 - accuracy: 0.9122 - val_loss: 8.5166 - val_accuracy: 0.0112
# Epoch 35/100
# 52/52 - 0s - loss: 0.1874 - accuracy: 0.9512 - val_loss: 8.5340 - val_accuracy: 0.0112
# Epoch 36/100
# 52/52 - 0s - loss: 0.2214 - accuracy: 0.9415 - val_loss: 8.5205 - val_accuracy: 0.0112
# Epoch 37/100
# 52/52 - 0s - loss: 0.1260 - accuracy: 0.9659 - val_loss: 8.5999 - val_accuracy: 0.0112
# Epoch 38/100
# 52/52 - 0s - loss: 0.1310 - accuracy: 0.9610 - val_loss: 8.6927 - val_accuracy: 0.0112
# Epoch 39/100
# 52/52 - 0s - loss: 0.1328 - accuracy: 0.9756 - val_loss: 8.7485 - val_accuracy: 0.0112
# Epoch 40/100
# 52/52 - 0s - loss: 0.1938 - accuracy: 0.9317 - val_loss: 8.6471 - val_accuracy: 0.0225
# Epoch 41/100
# 52/52 - 0s - loss: 0.2330 - accuracy: 0.9171 - val_loss: 8.7880 - val_accuracy: 0.0225
# Epoch 42/100
# 52/52 - 0s - loss: 0.1514 - accuracy: 0.9707 - val_loss: 8.7931 - val_accuracy: 0.0225
# Epoch 43/100
# 52/52 - 0s - loss: 0.0948 - accuracy: 0.9756 - val_loss: 8.8371 - val_accuracy: 0.0112
# Epoch 44/100
# 52/52 - 0s - loss: 0.0917 - accuracy: 0.9805 - val_loss: 8.8675 - val_accuracy: 0.0112
# Epoch 45/100
# 52/52 - 0s - loss: 0.1215 - accuracy: 0.9610 - val_loss: 8.9471 - val_accuracy: 0.0112
# Epoch 46/100
# 52/52 - 0s - loss: 0.1288 - accuracy: 0.9610 - val_loss: 9.0730 - val_accuracy: 0.0112
# Epoch 47/100
# 52/52 - 0s - loss: 0.1766 - accuracy: 0.9317 - val_loss: 8.9112 - val_accuracy: 0.0112
# Epoch 48/100
# 52/52 - 0s - loss: 0.1594 - accuracy: 0.9610 - val_loss: 9.1104 - val_accuracy: 0.0112
# Epoch 49/100
# 52/52 - 0s - loss: 0.1389 - accuracy: 0.9610 - val_loss: 9.0636 - val_accuracy: 0.0112
# Epoch 50/100
# 52/52 - 0s - loss: 0.2039 - accuracy: 0.9220 - val_loss: 9.1043 - val_accuracy: 0.0112
# Epoch 51/100
# 52/52 - 0s - loss: 0.1862 - accuracy: 0.9561 - val_loss: 9.0176 - val_accuracy: 0.0225
# Epoch 52/100
# 52/52 - 0s - loss: 0.1033 - accuracy: 0.9707 - val_loss: 9.0911 - val_accuracy: 0.0112
# Epoch 53/100
# 52/52 - 0s - loss: 0.0940 - accuracy: 0.9707 - val_loss: 9.2714 - val_accuracy: 0.0112
# Epoch 54/100
# 52/52 - 0s - loss: 0.1024 - accuracy: 0.9707 - val_loss: 9.2433 - val_accuracy: 0.0225
# Epoch 55/100
# 52/52 - 0s - loss: 0.1646 - accuracy: 0.9610 - val_loss: 9.1931 - val_accuracy: 0.0225
# Epoch 56/100
# 52/52 - 0s - loss: 0.1291 - accuracy: 0.9561 - val_loss: 9.3433 - val_accuracy: 0.0225
# Epoch 57/100
# 52/52 - 0s - loss: 0.0946 - accuracy: 0.9854 - val_loss: 9.3291 - val_accuracy: 0.0225
# Epoch 58/100
# 52/52 - 0s - loss: 0.1133 - accuracy: 0.9756 - val_loss: 9.4462 - val_accuracy: 0.0225
# Epoch 59/100
# 52/52 - 0s - loss: 0.1174 - accuracy: 0.9561 - val_loss: 9.4506 - val_accuracy: 0.0225
# Epoch 60/100
# 52/52 - 0s - loss: 0.0931 - accuracy: 0.9756 - val_loss: 9.5094 - val_accuracy: 0.0112
# Epoch 61/100
# 52/52 - 0s - loss: 0.1902 - accuracy: 0.9463 - val_loss: 9.4799 - val_accuracy: 0.0225
# Epoch 62/100
# 52/52 - 0s - loss: 0.1730 - accuracy: 0.9463 - val_loss: 9.4505 - val_accuracy: 0.0225
# Epoch 63/100
# 52/52 - 0s - loss: 0.1864 - accuracy: 0.9317 - val_loss: 9.6486 - val_accuracy: 0.0112
# Epoch 64/100
# 52/52 - 0s - loss: 0.1473 - accuracy: 0.9561 - val_loss: 9.6786 - val_accuracy: 0.0112
# Epoch 65/100
# 52/52 - 0s - loss: 0.1252 - accuracy: 0.9512 - val_loss: 9.5579 - val_accuracy: 0.0225
# Epoch 66/100
# 52/52 - 0s - loss: 0.1426 - accuracy: 0.9415 - val_loss: 9.5780 - val_accuracy: 0.0112
# Epoch 67/100
# 52/52 - 0s - loss: 0.1413 - accuracy: 0.9561 - val_loss: 9.5872 - val_accuracy: 0.0225
# Epoch 68/100
# 52/52 - 0s - loss: 0.2530 - accuracy: 0.9366 - val_loss: 9.6480 - val_accuracy: 0.0225
# Epoch 69/100
# 52/52 - 0s - loss: 0.0745 - accuracy: 0.9805 - val_loss: 9.6273 - val_accuracy: 0.0112
# Epoch 70/100
# 52/52 - 0s - loss: 0.1224 - accuracy: 0.9659 - val_loss: 9.6534 - val_accuracy: 0.0225
# Epoch 71/100
# 52/52 - 0s - loss: 0.1713 - accuracy: 0.9366 - val_loss: 9.7478 - val_accuracy: 0.0225
# Epoch 72/100
# 52/52 - 0s - loss: 0.0993 - accuracy: 0.9756 - val_loss: 9.7700 - val_accuracy: 0.0225
# Epoch 73/100
# 52/52 - 0s - loss: 0.1666 - accuracy: 0.9512 - val_loss: 9.7145 - val_accuracy: 0.0225
# Epoch 74/100
# 52/52 - 0s - loss: 0.1856 - accuracy: 0.9512 - val_loss: 9.6406 - val_accuracy: 0.0225
# Epoch 75/100
# 52/52 - 0s - loss: 0.1564 - accuracy: 0.9561 - val_loss: 9.6007 - val_accuracy: 0.0225
# Epoch 76/100
# 52/52 - 0s - loss: 0.0732 - accuracy: 0.9805 - val_loss: 9.6438 - val_accuracy: 0.0225
# Epoch 77/100
# 52/52 - 0s - loss: 0.1558 - accuracy: 0.9512 - val_loss: 9.7045 - val_accuracy: 0.0225
# Epoch 78/100
# 52/52 - 0s - loss: 0.0705 - accuracy: 0.9659 - val_loss: 9.7444 - val_accuracy: 0.0225
# Epoch 79/100
# 52/52 - 0s - loss: 0.2413 - accuracy: 0.9463 - val_loss: 9.7665 - val_accuracy: 0.0112
# Epoch 80/100
# 52/52 - 0s - loss: 0.1268 - accuracy: 0.9512 - val_loss: 9.8795 - val_accuracy: 0.0112
# Epoch 81/100
# 52/52 - 0s - loss: 0.1153 - accuracy: 0.9659 - val_loss: 9.7774 - val_accuracy: 0.0112
# Epoch 82/100
# 52/52 - 0s - loss: 0.2170 - accuracy: 0.9317 - val_loss: 9.8697 - val_accuracy: 0.0225
# Epoch 83/100
# 52/52 - 0s - loss: 0.1965 - accuracy: 0.9512 - val_loss: 9.8965 - val_accuracy: 0.0225
# Epoch 84/100
# 52/52 - 0s - loss: 0.0636 - accuracy: 0.9756 - val_loss: 9.8430 - val_accuracy: 0.0112
# Epoch 85/100
# 52/52 - 0s - loss: 0.1447 - accuracy: 0.9512 - val_loss: 9.7207 - val_accuracy: 0.0112
# Epoch 86/100
# 52/52 - 0s - loss: 0.1780 - accuracy: 0.9512 - val_loss: 9.8406 - val_accuracy: 0.0225
# Epoch 87/100
# 52/52 - 0s - loss: 0.1269 - accuracy: 0.9561 - val_loss: 9.8965 - val_accuracy: 0.0225
# Epoch 88/100
# 52/52 - 0s - loss: 0.1105 - accuracy: 0.9659 - val_loss: 9.8061 - val_accuracy: 0.0225
# Epoch 89/100
# 52/52 - 0s - loss: 0.1419 - accuracy: 0.9561 - val_loss: 9.7166 - val_accuracy: 0.0337
# Epoch 90/100
# 52/52 - 0s - loss: 0.1639 - accuracy: 0.9463 - val_loss: 9.9154 - val_accuracy: 0.0449
# Epoch 91/100
# 52/52 - 0s - loss: 0.1480 - accuracy: 0.9561 - val_loss: 10.0541 - val_accuracy: 0.0337
# Epoch 92/100
# 52/52 - 0s - loss: 0.1685 - accuracy: 0.9317 - val_loss: 9.9106 - val_accuracy: 0.0337
# Epoch 93/100
# 52/52 - 0s - loss: 0.1418 - accuracy: 0.9512 - val_loss: 10.0718 - val_accuracy: 0.0225
# Epoch 94/100
# 52/52 - 0s - loss: 0.1525 - accuracy: 0.9366 - val_loss: 9.8883 - val_accuracy: 0.0225
# Epoch 95/100
# 52/52 - 0s - loss: 0.1238 - accuracy: 0.9659 - val_loss: 9.9744 - val_accuracy: 0.0337
# Epoch 96/100
# 52/52 - 0s - loss: 0.1294 - accuracy: 0.9463 - val_loss: 9.9415 - val_accuracy: 0.0225
# Epoch 97/100
# 52/52 - 0s - loss: 0.1195 - accuracy: 0.9463 - val_loss: 10.0729 - val_accuracy: 0.0225
# Epoch 98/100
# 52/52 - 0s - loss: 0.1491 - accuracy: 0.9659 - val_loss: 9.9769 - val_accuracy: 0.0225
# Epoch 99/100
# 52/52 - 0s - loss: 0.1206 - accuracy: 0.9463 - val_loss: 9.9984 - val_accuracy: 0.0225
# Epoch 100/100
# 52/52 - 0s - loss: 0.1082 - accuracy: 0.9659 - val_loss: 10.0752 - val_accuracy: 0.0225

# %%
import matplotlib.pyplot as plt
print(history.history.keys())
# Model Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Model Loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import pandas as pd
result = pd.DataFrame(
    [history.history['loss'],history.history['val_loss'],history.history['accuracy'],history.history['val_accuracy']],
    index=["loss","val_loss","accuracy","val_accuracy"],
    columns=[f'epoch_{num + 1}' for num in range(100)])

result
# Out:
#                epoch_1   epoch_2   epoch_3   epoch_4   epoch_5   epoch_6  \
# loss          3.805625  2.428004  1.745479  1.395299  1.006170  0.810532
# val_loss      5.448349  5.976146  6.296424  6.536618  6.671312  6.835421
# accuracy      0.024390  0.429268  0.634146  0.741463  0.800000  0.863415
# val_accuracy  0.000000  0.000000  0.011236  0.011236  0.022472  0.022472
#
#                epoch_7   epoch_8   epoch_9  epoch_10  ...   epoch_91  \
# loss          0.624824  0.536442  0.500260  0.462553  ...   0.148036
# val_loss      6.955673  7.093194  7.224093  7.315912  ...  10.054066
# accuracy      0.907317  0.902439  0.921951  0.912195  ...   0.956098
# val_accuracy  0.011236  0.011236  0.011236  0.011236  ...   0.033708
#
#               epoch_92   epoch_93  epoch_94  epoch_95  epoch_96   epoch_97  \
# loss          0.168508   0.141810  0.152500  0.123831  0.129403   0.119494
# val_loss      9.910630  10.071819  9.888276  9.974381  9.941544  10.072932
# accuracy      0.931707   0.951219  0.936585  0.965854  0.946341   0.946341
# val_accuracy  0.033708   0.022472  0.022472  0.033708  0.022472   0.022472
#
#               epoch_98  epoch_99  epoch_100
# loss          0.149134  0.120644   0.108216
# val_loss      9.976923  9.998441  10.075235
# accuracy      0.965854  0.946341   0.965854
# val_accuracy  0.022472  0.022472   0.022472
#
# [4 rows x 100 columns]
